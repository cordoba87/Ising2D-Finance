# %%
import numpy as np
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
from scipy.stats import linregress
import requests
import io

# ==========================================
# 1. INFRAESTRUCTURA DE DATOS Y ORDENACIÓN TOPOLÓGICA
# ==========================================
print("1/2: Descargando universo ampliado y construyendo topología sectorial...")
headers = {'User-Agent': 'Mozilla/5.0'}

def extraer_indice_wiki(url):
    html = requests.get(url, headers=headers).text
    dfs = pd.read_html(io.StringIO(html))
    
    # Posibles identificadores de columnas en Wikipedia
    ticker_cols = ['Symbol', 'Ticker', 'Ticker symbol']
    sector_cols = ['GICS Sector', 'Sector', 'Industry']
    
    for df in dfs:
        # Aplanar MultiIndex si la tabla tiene cabeceras anidadas
        if isinstance(df.columns, pd.MultiIndex):
            df.columns = df.columns.get_level_values(-1)
            
        # Buscar columna de Ticker
        col_ticker = next((c for c in ticker_cols if c in df.columns), None)
        
        if col_ticker:
            # Buscar columna de Sector
            col_sector = next((c for c in sector_cols if c in df.columns), None)
            
            if not col_sector:
                df['Sector'] = 'Z_Unassigned'
                col_sector = 'Sector'
                
            res = df[[col_ticker, col_sector]].copy()
            res = res.rename(columns={col_ticker: 'Symbol', col_sector: 'Sector'})
            res['Symbol'] = res['Symbol'].astype(str).str.replace('.', '-', regex=False)
            return res
            
    raise ValueError(f"CRÍTICO: No se encontró ninguna tabla válida con activos en {url}")

# Extracción robusta sin depender de un 'match_str' estricto
sp500 = extraer_indice_wiki('https://en.wikipedia.org/wiki/List_of_S%26P_500_companies')
sp400 = extraer_indice_wiki('https://en.wikipedia.org/wiki/List_of_S%26P_400_companies')
sp600 = extraer_indice_wiki('https://en.wikipedia.org/wiki/List_of_S%26P_600_companies')
russell = extraer_indice_wiki('https://en.wikipedia.org/wiki/Russell_1000_Index')

# Unificamos asegurando que no haya duplicados
df_universo = pd.concat([sp500, sp400, sp600, russell], ignore_index=True).drop_duplicates(subset=['Symbol'])
all_tickers = df_universo['Symbol'].tolist()

print(f"Total de activos únicos iniciales: {len(all_tickers)}")

# Descarga de VIX y datos
vix_raw = yf.download("^VIX", start="2017-01-01", end="2018-12-31", progress=False)['Close']
all_data = yf.download(all_tickers, start="2017-01-01", end="2018-12-31", progress=False)

if isinstance(all_data.columns, pd.MultiIndex): 
    all_data = all_data['Close']

# Purga estricta de supervivencia (retornos)
returns_all = all_data.pct_change().dropna(how='all').dropna(axis=1)
activos_supervivientes = returns_all.columns.tolist()

# Mapeamos los supervivientes a sus sectores y ordenamos
df_supervivientes = df_universo[df_universo['Symbol'].isin(activos_supervivientes)].copy()
df_supervivientes = df_supervivientes.sort_values(by='Sector')

N_requerido = 1024
if len(df_supervivientes) < N_requerido:
    raise ValueError(f"Fallo crítico: Sobrevivieron {len(df_supervivientes)} activos. Se exigen {N_requerido}.")

# Truncamos a N=1024 exactos preservando la topología sectorial
tickers_finales = df_supervivientes['Symbol'].tolist()[:N_requerido]
returns_real_base = returns_all[tickers_finales]
vix_sincro = vix_raw.reindex(returns_real_base.index).ffill()

print(f"Matriz empírica ordenada sectorialmente con dimensiones exactas {returns_real_base.shape} (N={N_requerido}).")

# ==========================================
# 2. FILTRADO VIX (ENSAMBLE CUASI-ESTACIONARIO)
# ==========================================
print("2/2: Aplicando filtro termodinámico VIX...")
q_low = vix_sincro.quantile(0.70).values[0]
q_high = vix_sincro.quantile(0.95).values[0]

mask_critica = (vix_sincro.values.flatten() >= q_low) & (vix_sincro.values.flatten() <= q_high)
returns_filt = returns_real_base.iloc[mask_critica, :]

plt.figure(figsize=(15, 5))
plt.plot(vix_sincro.index, vix_sincro.values, color='black', alpha=0.3, label='VIX (Descartado)')
plt.scatter(vix_sincro.index[mask_critica], vix_sincro.values[mask_critica], 
            color='red', s=15, label='Régimen Seleccionado [Q70, Q95]')
plt.axhline(q_low, color='blue', linestyle='--', label=f'Q70 ({q_low:.2f})')
plt.axhline(q_high, color='darkred', linestyle='--', label=f'Q95 ({q_high:.2f})')
plt.title("Selección de Estados mediante Filtro de Banda VIX")
plt.ylabel("VIX Index"); plt.legend(); plt.grid(True, alpha=0.2)
plt.show()
# Out:
# 1/2: Descargando universo ampliado y construyendo topología sectorial...
# Total de activos únicos iniciales: 1637
# $COIN: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $FOUR: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $SNCY: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $GXO: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $HOOD: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $SFD: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $CCC: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $VSNT: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $CERT: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $LLYVA: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $CHWY: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $ONON: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $XPEL: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $DJT: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $NVST: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $SARO: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $VLTO: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $BRBR: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $WAY: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $RKLB: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $RBLX: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $VSTS: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $SNOW: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $GFS: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $MBC: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $AFRM: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# Failed to get ticker 'RKT' reason: Failed to perform, curl: (28) Connection timed out after 10005 milliseconds. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.
# $RKT: possibly delisted; no timezone found
# $AESI: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $EMBC: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $SLVM: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $RBRK: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $CRSR: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $GTLB: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $SEZL: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $TMDX: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $PSN: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $LTH: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $CAI: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $CFLT: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $CART: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $VIK: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $RVMD: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $KD: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $KGS: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $DV: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $DOCN: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $FOX: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $ACT: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $SNDK: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $OGN: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $BSY: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $BROS: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $RPRX: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $KRMN: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $ESAB: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $LCID: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $S: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $LINE: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $SOLV: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $SOLS: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $PATH: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $PRVA: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $FOXA: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $SDGR: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $EXE: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $DOW: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $LLYVK: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $NXT: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $CXM: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $CON: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $RAL: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $CNXC: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $VAL: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $DT: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $OWL: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $MIR: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $FBRT: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $BTSG: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $CRGY: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $DTM: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $BAM: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $TIGO: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $LYFT: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $FTRE: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $RDDT: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $SHC: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $ZM: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $BEPC: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $JXN: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $ACI: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $FRMI: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $AVTR: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $AHR: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $ECG: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $PINS: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $DASH: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $APP: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $MRP: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $CAVA: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $ABNB: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $PECO: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $NATL: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $DDOG: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $INGM: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $CARR: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $CRBG: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $BLSH: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $IOT: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $HTZ: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $RIVN: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $CRCL: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $QS: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $UBER: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $SN: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $U: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $ONTO: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $VITL: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $TOST: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $FIGR: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $CNM: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $NABL: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $ASTS: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $GEV: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $CURB: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $NET: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $KVUE: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $SAIL: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $SOFI: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $NCNO: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $DKNG: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $PAYO: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $TPG: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $NIQ: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $LIF: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $NU: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $CRC: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $UWMC: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $APG: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $GEHC: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $CPNG: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $PLMR: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $ALAB: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $PHIN: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $TEM: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $BIRK: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $AMTM: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $CRWD: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $PLTR: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $CR: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $TW: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $GLIBK: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $STEP: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $WFRD: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $PGNY: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $NE: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $KTB: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $RYAN: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $KNF: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $HRMY: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $REYN: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $BILL: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $LOAR: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $Q: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $HIMS: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $ROIV: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $HAYW: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $CTKB: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $DOCS: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $OTIS: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $AUR: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $VIR: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $VSCO: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $WMG: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $WS: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $ASO: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $AS: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $ALGM: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $LZ: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $AMR: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $MCW: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $GTM: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $MP: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $DFH: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $CEG: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $SPHR: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $GLIBA: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $XP: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $UHAL-B: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $TLN: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $DUOL: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $GO: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $CTVA: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $YOU: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $ULS: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $VNT: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# $PCOR: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
#
# 201 Failed downloads:
# ['COIN', 'FOUR', 'SNCY', 'GXO', 'HOOD', 'SFD', 'CCC', 'VSNT', 'CERT', 'LLYVA', 'CHWY', 'ONON', 'XPEL', 'DJT', 'NVST', 'SARO', 'VLTO', 'BRBR', 'WAY', 'RKLB', 'RBLX', 'VSTS', 'SNOW', 'GFS', 'MBC', 'AFRM', 'AESI', 'EMBC', 'SLVM', 'RBRK', 'CRSR', 'GTLB', 'SEZL', 'TMDX', 'PSN', 'LTH', 'CAI', 'CFLT', 'CART', 'VIK', 'RVMD', 'KD', 'KGS', 'DV', 'DOCN', 'FOX', 'ACT', 'SNDK', 'OGN', 'BSY', 'BROS', 'RPRX', 'KRMN', 'ESAB', 'LCID', 'S', 'LINE', 'SOLV', 'SOLS', 'PATH', 'PRVA', 'FOXA', 'SDGR', 'EXE', 'DOW', 'LLYVK', 'NXT', 'CXM', 'CON', 'RAL', 'CNXC', 'VAL', 'DT', 'OWL', 'MIR', 'FBRT', 'BTSG', 'CRGY', 'DTM', 'BAM', 'TIGO', 'LYFT', 'FTRE', 'RDDT', 'SHC', 'ZM', 'BEPC', 'JXN', 'ACI', 'FRMI', 'AVTR', 'AHR', 'ECG', 'PINS', 'DASH', 'APP', 'MRP', 'CAVA', 'ABNB', 'PECO', 'NATL', 'DDOG', 'INGM', 'CARR', 'CRBG', 'BLSH', 'IOT', 'HTZ', 'RIVN', 'CRCL', 'QS', 'UBER', 'SN', 'U', 'ONTO', 'VITL', 'TOST', 'FIGR', 'CNM', 'NABL', 'ASTS', 'GEV', 'CURB', 'NET', 'KVUE', 'SAIL', 'SOFI', 'NCNO', 'DKNG', 'PAYO', 'TPG', 'NIQ', 'LIF', 'NU', 'CRC', 'UWMC', 'APG', 'GEHC', 'CPNG', 'PLMR', 'ALAB', 'PHIN', 'TEM', 'BIRK', 'AMTM', 'CRWD', 'PLTR', 'CR', 'TW', 'GLIBK', 'STEP', 'WFRD', 'PGNY', 'NE', 'KTB', 'RYAN', 'KNF', 'HRMY', 'REYN', 'BILL', 'LOAR', 'Q', 'HIMS', 'ROIV', 'HAYW', 'CTKB', 'DOCS', 'OTIS', 'AUR', 'VIR', 'VSCO', 'WMG', 'WS', 'ASO', 'AS', 'ALGM', 'LZ', 'AMR', 'MCW', 'GTM', 'MP', 'DFH', 'CEG', 'SPHR', 'GLIBA', 'XP', 'UHAL-B', 'TLN', 'DUOL', 'GO', 'CTVA', 'YOU', 'ULS', 'VNT', 'PCOR']: possibly delisted; no price data found  (1d 2017-01-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1483246800, endDate = 1546232400")
# ['RXO', 'CBRL', 'REXR', 'LZB', 'RDN']: TypeError("'NoneType' object is not subscriptable")
# ['RKT']: possibly delisted; no timezone found
# Matriz empírica ordenada sectorialmente con dimensiones exactas (500, 1024) (N=1024).
# 2/2: Aplicando filtro termodinámico VIX...

# %%
# ==========================================
# 3. CÁLCULO DE OBSERVABLES (FILTRADO VIX)
# ==========================================
tamaños_L = [8, 16, 32]
res_vix = {}

print(f"Calculando observables para {len(returns_filt)} días de criticidad...")

for L in tamaños_L:
    N = L * L
    
    # --- BLOQUE DE SEGURIDAD: COMPROBACIÓN DE DIMENSIONES ---
    n_disponibles = returns_filt.shape[1]
    if n_disponibles < N:
        print(f"Aviso: Solo hay {n_disponibles} activos. Completando {N-n_disponibles} con bootstrapping para L={L}...")
        # Muestreamos con reemplazo de los activos existentes para llegar a N
        extra = returns_filt.sample(n=N-n_disponibles, axis=1, replace=True)
        # Concatenamos para asegurar que la matriz de espines sea exactamente de tamaño N
        ret_L = pd.concat([returns_filt, extra], axis=1)
    else:
        ret_L = returns_filt.iloc[:, :N]

    # Extracción de espines
    spins = np.sign(ret_L.values)
    spins[spins == 0] = 1 
    
    # 1. Magnetización: <|M|>
    m_t = np.abs(np.mean(spins, axis=1))
    m_mean = np.mean(m_t)
    
    # 2. Susceptibilidad: chi = N * Var(M_temporal)
    m_temporal = np.mean(spins, axis=1)
    chi_emp = np.var(m_temporal) * N
    
    # 3. Energía y Calor Específico (Topología 2D)
    edges = []
    for i in range(N):
        r, c = i // L, i % L
        vecinos = [((r - 1) % L) * L + c, ((r + 1) % L) * L + c, 
                   r * L + (c - 1) % L, r * L + (c + 1) % L]
        for v in vecinos:
            if i < v: 
                edges.append((i, v))
    
    edges = np.array(edges)
    si = spins[:, edges[:, 0]]
    sj = spins[:, edges[:, 1]]
    
    # E = - (1/N) * sum(s_i * s_j)
    E_t = -np.sum(si * sj, axis=1) / float(N)
    c_emp = np.var(E_t) * N
    
    res_vix[L] = {'M': m_mean, 'Chi': chi_emp, 'C': c_emp}
    # --- NUEVO: Longitud de Correlación (xi) ---
    # Generar coordenadas de la red
    x_coords = np.arange(L)
    # Momento mínimo k = (2*pi/L, 0)
    # Calculamos la parte real e imaginaria de la transformada de Fourier
    # spins tiene forma (días, N), proyectamos a 2D para la fase
    spins_2d = spins.reshape(-1, L, L)
    
    # Proyección sobre el eje x para el momento (2*pi/L, 0)
    fase = 2 * np.pi * x_coords / L
    cos_f = np.cos(fase)
    sin_f = np.sin(fase)
    
    # Suma sobre x e y (reducimos el eje y primero, luego el x con la fase)
    m1r = np.sum(np.sum(spins_2d, axis=1) * cos_f, axis=1)
    m1i = np.sum(np.sum(spins_2d, axis=1) * sin_f, axis=1)
    
    # F10 es el factor de estructura a momento mínimo (normalizado por V^2)
    f10_t = (m1r**2 + m1i**2) / (N**2)
    f10_mean = np.mean(f10_t)
    
    # xi = [sqrt(M2/F10 - 1)] / [2 * sin(pi/L)]
    m2_mean = np.mean(m_temporal**2) # <M^2>
    ratio = (m2_mean / f10_mean) - 1
    xi_val = np.sqrt(max(0, ratio)) / (2 * np.sin(np.pi / L))
    
    # Guardar en el diccionario
    res_vix[L] = {'M': m_mean, 'Chi': chi_emp, 'C': c_emp, 'Xi': xi_val}

# ==========================================
# 4. AJUSTES LOG-LOG Y EXTRACCIÓN DE RATIOS
# ==========================================
L_vals = np.array(tamaños_L)
log_L = np.log(L_vals)

def get_fit_vix(key):
    y_data = np.array([res_vix[L][key] for L in tamaños_L])
    y_data = np.where(y_data > 0, y_data, 1e-12)
    log_y = np.log(y_data)
    
    slope, intercept, r_val, p_val, stderr = linregress(log_L, log_y)
    return slope, stderr, (intercept + slope * log_L), log_y

b_M, sb_M, fit_M, log_M_d = get_fit_vix('M')
b_M = abs(b_M) 
b_Chi, sb_Chi, fit_Chi, log_Chi_d = get_fit_vix('Chi')
b_C, sb_C, fit_C, log_C_d = get_fit_vix('C')
b_Xi, sb_Xi, fit_Xi, log_Xi_data = get_fit_vix('Xi')

# ==========================================
# 5. EXPONENTES CRÍTICOS (RELACIONES DE ESCALA)
# ==========================================
# nu (Rushbrooke): nu = 2 / (b_C + 2*b_M + b_Chi)
den = b_C + 2*b_M + b_Chi
nu_e = 2.0 / den
sn_e = (nu_e**2 / 2.0) * np.sqrt(sb_C**2 + 4*sb_M**2 + sb_Chi**2)

def prop_prod(b, sb, nu, sn):
    if b == 0 or nu == 0: return 0.0, 0.0
    val = b * nu
    err = abs(val) * np.sqrt((sb/b)**2 + (sn/nu)**2)
    return val, err

alpha_e, sa_e = prop_prod(b_C, sb_C, nu_e, sn_e)
beta_e, sb_e   = prop_prod(b_M, sb_M, nu_e, sn_e)
gamma_e, sg_e = prop_prod(b_Chi, sb_Chi, nu_e, sn_e)

delta_e = 1.0 + (gamma_e / beta_e) if beta_e != 0 else float('inf')
sd_e = (gamma_e/beta_e) * np.sqrt((sg_e/gamma_e)**2 + (sb_e/beta_e)**2) if beta_e != 0 else 0
eta_e = 2.0 - b_Chi
sigma_eta = sb_Chi

# ==========================================
# 6. TABLA COMPARATIVA FINAL (SIGMAS)
# ==========================================
print("\n" + "="*85)
print(f"{'EXPONENTE':<15} | {'VALOR (VIX FILTERED)':<20} | {'ONSAGER (2D)':<12} | {'C. MEDIO':<12}")
print("="*85)

exps = [
    ('nu', nu_e, sn_e, 1.0, 0.5),
    ('alpha', alpha_e, sa_e, 0.0, 0.0),
    ('beta', beta_e, sb_e, 0.125, 0.5),
    ('gamma', gamma_e, sg_e, 1.75, 1.0),
    ('delta', delta_e, sd_e, 15.0, 3.0),
    ('eta', eta_e, sigma_eta, 0.25, 0.0),
    ('nu_slope', b_Xi, sb_Xi, 1.0, 1.0)
]

for n, v, e, o, m in exps:
    s_o = abs(v-o)/e if e > 1e-12 else float('inf')
    s_m = abs(v-m)/e if e > 1e-12 else float('inf')
    print(f"{n:<15} | {v:>7.3f} ± {e:<8.3f} | {o:>5.2f} ({s_o:>4.1f}σ) | {m:>5.2f} ({s_m:>4.1f}σ)")
print("="*85)

# ==========================================
# 7. EXPORTACIÓN CAIRO PDF (CON ERROR DE AJUSTE)
# ==========================================
def export_cairo_vix(x, y, y_fit, slope, stderr, title, fname, color):
    fig, ax = plt.subplots(figsize=(6, 5))
    ax.scatter(x, y, color=color, s=80, label='Datos (VIX)', zorder=3)
    
    # Se incluye el error estándar (stderr) en el label de la leyenda
    label_fit = rf'Pendiente: ${slope:.4f} \pm {stderr:.4f}$'
    ax.plot(x, y_fit, 'k--', label=label_fit, linewidth=1.5, zorder=2)
    
    ax.set_title(title)
    ax.set_xlabel(r"$\ln(L)$")
    ax.set_ylabel(r"$\ln(O)$")
    ax.grid(True, linestyle=':', alpha=0.6)
    ax.legend()
    fig.tight_layout()
    
    # Exportación usando el backend de Cairo
    plt.savefig(fname, format='pdf', backend='cairo', bbox_inches='tight')
    plt.show()

# Llamadas actualizadas pasando el error (sb_X) correspondiente:
export_cairo_vix(log_L, log_M_d, fit_M, b_M, sb_M, "FSS Magnetización (VIX)", "FSS_VIX_M.pdf", "blue")
export_cairo_vix(log_L, log_Chi_d, fit_Chi, b_Chi, sb_Chi, "FSS Susceptibilidad (VIX)", "FSS_VIX_Chi.pdf", "red")
export_cairo_vix(log_L, log_C_d, fit_C, b_C, sb_C, "FSS Calor Específico (VIX)", "FSS_VIX_C.pdf", "green")
export_cairo_vix(log_L, log_Xi_data, fit_Xi, b_Xi, sb_Xi, "FSS Longitud de Correlación (VIX)", "FSS_VIX_Xi.pdf", "purple")
# Out:
# Calculando observables para 126 días de criticidad...
#
# =====================================================================================
# EXPONENTE       | VALOR (VIX FILTERED) | ONSAGER (2D) | C. MEDIO
# =====================================================================================
# nu              |   0.526 ± 0.032    |  1.00 (14.8σ) |  0.50 ( 0.8σ)
# alpha           |   0.922 ± 0.105    |  0.00 ( 8.8σ) |  0.00 ( 8.8σ)
# beta            |   0.013 ± 0.030    |  0.12 ( 3.8σ) |  0.50 (16.4σ)
# gamma           |   1.052 ± 0.086    |  1.75 ( 8.1σ) |  1.00 ( 0.6σ)
# delta           |  82.709 ± 188.739  | 15.00 ( 0.4σ) |  3.00 ( 0.4σ)
# eta             |   0.002 ± 0.109    |  0.25 ( 2.3σ) |  0.00 ( 0.0σ)
# nu_slope        |   2.103 ± 0.098    |  1.00 (11.2σ) |  1.00 (11.2σ)
# =====================================================================================
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
