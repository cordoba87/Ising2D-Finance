# %%
# !pip install lxml html5lib requests
# Out:
# Requirement already satisfied: lxml in .\.venv\Lib\site-packages (6.0.2)
# Requirement already satisfied: html5lib in .\.venv\Lib\site-packages (1.1)
# Requirement already satisfied: requests in .\.venv\Lib\site-packages (2.32.5)
# Requirement already satisfied: six>=1.9 in .\.venv\Lib\site-packages (from html5lib) (1.17.0)
# Requirement already satisfied: webencodings in .\.venv\Lib\site-packages (from html5lib) (0.5.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in .\.venv\Lib\site-packages (from requests) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in .\.venv\Lib\site-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in .\.venv\Lib\site-packages (from requests) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in .\.venv\Lib\site-packages (from requests) (2026.2.25)

# %%
import numpy as np
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt

# %%
import numpy as np
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt

# ==========================================
# 1. FUNCIONES CORE (Física Estadística)
# ==========================================
def swendsen_wang_fast(spins, p_bond, edges, N):
    parent = np.arange(N)
    
    def find(i):
        root = i
        while root != parent[root]: root = parent[root]
        curr = i
        while curr != root:
            nxt = parent[curr]
            parent[curr] = root
            curr = nxt
        return root

    def union(i, j):
        r_i, r_j = find(i), find(j)
        if r_i != r_j: parent[r_i] = r_j

    s_i = spins[edges[:, 0]]
    s_j = spins[edges[:, 1]]
    active = (s_i == s_j) & (np.random.rand(len(edges)) < p_bond)
    
    for u, v in edges[active]: union(u, v)
        
    roots = np.array([find(i) for i in range(N)])
    unique_roots = np.unique(roots)
    new_spins = np.random.choice([-1, 1], size=len(unique_roots))
    root_to_spin = dict(zip(unique_roots, new_spins))
    
    return np.array([root_to_spin[r] for r in roots])

def calc_fourier_y_xi(spins_1d_array, L):
    spins_2d = spins_1d_array.reshape(-1, L, L)
    V = L * L
    M = np.sum(spins_2d, axis=(1, 2))
    M2 = (M / V)**2
    
    k_vec = 2 * np.pi * np.arange(L) / L
    cos_k = np.cos(k_vec)
    sin_k = np.sin(k_vec)
    
    sum_y = np.sum(spins_2d, axis=1) 
    sum_x = np.sum(spins_2d, axis=2) 
    
    mod_X2 = np.dot(sum_y, cos_k)**2 + np.dot(sum_y, sin_k)**2
    mod_Y2 = np.dot(sum_x, cos_k)**2 + np.dot(sum_x, sin_k)**2
    
    F10 = 0.5 * (mod_X2 + mod_Y2) / (V * V)
    return M2, F10

def formula_xi(m2, f10, L):
    ratio = m2 / f10 - 1.0
    ratio[ratio < 0] = 0 
    return np.sqrt(ratio) / (2.0 * np.sin(np.pi / L))

import pandas as pd
import yfinance as yf
import numpy as np
import requests
import io

# ==========================================
# 2. DESCARGA DEL S&P 1500 (TOPOLOGÍA ALFABÉTICA / ALEATORIZADA)
# ==========================================
print("Extrayendo S&P 1500 oficial... (Ordenando ALFABÉTICAMENTE para el experimento de control)")

headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36'}

def extraer_indice_wiki(url):
    html = requests.get(url, headers=headers).text
    df = pd.read_html(io.StringIO(html))[0]
    col_ticker = 'Symbol' if 'Symbol' in df.columns else 'Ticker'
    col_sector = 'GICS Sector' if 'GICS Sector' in df.columns else 'Sector'
    return df[[col_ticker, col_sector]].rename(columns={col_ticker: 'Symbol', col_sector: 'Sector'})

sp500 = extraer_indice_wiki('https://en.wikipedia.org/wiki/List_of_S%26P_500_companies')
sp400 = extraer_indice_wiki('https://en.wikipedia.org/wiki/List_of_S%26P_400_companies')
sp600 = extraer_indice_wiki('https://en.wikipedia.org/wiki/List_of_S%26P_600_companies')

df_sp1500 = pd.concat([sp500, sp400, sp600], ignore_index=True)
df_sp1500 = df_sp1500.drop_duplicates(subset=['Symbol'])

# ========================================================
# EL CAMBIO CRÍTICO: ORDENAMOS ALFABÉTICAMENTE POR TICKER
# ========================================================
df_sp1500 = df_sp1500.sort_values(by='Symbol')

all_tickers = [str(t).replace('.', '-') for t in df_sp1500['Symbol'].tolist()]

print(f"Total empresas encontradas: {len(all_tickers)}. Descargando años 2011-2012...")
data = yf.download(all_tickers, start="2011-01-01", end="2012-12-31", progress=False)

if isinstance(data.columns, pd.MultiIndex):
    data = data['Close']

tickers_descargados = data.columns.tolist()
tickers_ordenados = [t for t in all_tickers if t in tickers_descargados]
data = data[tickers_ordenados]

returns_real_base = data.pct_change().dropna(how='all').dropna(axis=1)

print(f"Han sobrevivido {returns_real_base.shape[1]} empresas.")

if returns_real_base.shape[1] >= 1024:
    returns_real_base = returns_real_base.iloc[:, :1024]
    print(f"¡Matriz ALFABÉTICA de {returns_real_base.shape[1]} empresas lista para L=32!")
else:
    raise ValueError(f"FALTAN EMPRESAS: Solo sobrevivieron {returns_real_base.shape[1]}.")
# 3. BUCLE PRINCIPAL DE EXPERIMENTOS
# ==========================================
tamaños_L = [8, 16, 32]
vent = 20 # Ventana móvil
K_c = 0.5 * np.log(1 + np.sqrt(2))
p_bond = 1.0 - np.exp(-2.0 * K_c)

resultados = {'sim': {}, 'real': {}}

for L in tamaños_L:
    N = L * L
    print(f"\n--- Procesando Red de {L}x{L} (N={N}) ---")
    
    # --- A) DATOS REALES ---
    ret_real_N = returns_real_base.copy()
    
    # Relleno de seguridad si faltan empresas (Clonación segura para evitar bucles infinitos)
    intentos = 0
    while ret_real_N.shape[1] < N and intentos < 100:
        faltan = N - ret_real_N.shape[1]
        clon = returns_real_base.sample(n=min(returns_real_base.shape[1], faltan), axis=1)
        clon.columns = [f"CLON_{ret_real_N.shape[1] + i}" for i in range(clon.shape[1])]
        ret_real_N = pd.concat([ret_real_N, clon], axis=1)
        intentos += 1
        
    ret_real_N = ret_real_N.iloc[:, :N]
    spins_real = np.sign(ret_real_N).replace(0, 1).values
    
    M_real = np.mean(spins_real, axis=1)
    M2_real, F10_real = calc_fourier_y_xi(spins_real, L)
    
    Chi_real = pd.Series(M_real).rolling(window=vent).var().values * N
    M2_r_roll = pd.Series(M2_real).rolling(window=vent).mean().values
    F10_r_roll = pd.Series(F10_real).rolling(window=vent).mean().values
    Xi_real = formula_xi(M2_r_roll, F10_r_roll, L)
    
    resultados['real'][L] = {'M': np.abs(M_real), 'Chi': Chi_real, 'Xi': Xi_real}

    # --- B) SIMULACIÓN MONTE CARLO ---
    edges = []
    for index in range(N):
        row, col = index // L, index % L
        vecinos = [((row - 1) % L) * L + col, ((row + 1) % L) * L + col, row * L + (col - 1) % L, row * L + (col + 1) % L]
        for v in vecinos:
            if index < v: edges.append((index, v))
    edges = np.array(edges)
    
    estado = np.random.choice([-1, 1], size=N)
    for _ in range(200): estado = swendsen_wang_fast(estado, p_bond, edges, N)
        
    spins_sim = []
    for _ in range(num_dias):
        estado = swendsen_wang_fast(estado, p_bond, edges, N)
        spins_sim.append(estado.copy())
    spins_sim = np.array(spins_sim)
    
    M_sim = np.mean(spins_sim, axis=1)
    M2_sim, F10_sim = calc_fourier_y_xi(spins_sim, L)
    
    Chi_sim = pd.Series(M_sim).rolling(window=vent).var().values * N
    M2_s_roll = pd.Series(M2_sim).rolling(window=vent).mean().values
    F10_s_roll = pd.Series(F10_sim).rolling(window=vent).mean().values
    Xi_sim = formula_xi(M2_s_roll, F10_s_roll, L)
    
    resultados['sim'][L] = {'M': np.abs(M_sim), 'Chi': Chi_sim, 'Xi': Xi_sim}

# ==========================================
# 4. PLOTS 
# ==========================================
print("\nGenerando gráficos...")
colores = {8: 'royalblue', 16: 'darkorange', 32: 'crimson'}

# --- FIGURA 1: SIMULACIONES ---
fig1, axs1 = plt.subplots(3, 1, figsize=(12, 12), sharex=True)
fig1.suptitle('FIGURA 1: SIMULACIONES MONTE CARLO (Punto Crítico Tc)', fontsize=16, y=0.98)
for L in tamaños_L:
    axs1[0].plot(fechas, resultados['sim'][L]['M'], label=f'L={L}', color=colores[L], alpha=0.8)
    axs1[1].plot(fechas, resultados['sim'][L]['Chi'], label=f'L={L}', color=colores[L], alpha=0.8)
    axs1[2].plot(fechas, resultados['sim'][L]['Xi'], label=f'L={L}', color=colores[L], alpha=0.8)

axs1[0].set_ylabel('|M|'); axs1[0].legend(); axs1[0].grid(True, alpha=0.3)
axs1[1].set_ylabel(r'$\chi$'); axs1[1].legend(); axs1[1].grid(True, alpha=0.3)
axs1[2].set_ylabel(r'$\xi$'); axs1[2].legend(); axs1[2].grid(True, alpha=0.3)
plt.tight_layout()

# --- FIGURA 2: DATOS REALES ---
fig2, axs2 = plt.subplots(3, 1, figsize=(12, 12), sharex=True)
fig2.suptitle('FIGURA 2: DATOS REALES DEL MERCADO', fontsize=16, y=0.98)
for L in tamaños_L:
    axs2[0].plot(fechas, resultados['real'][L]['M'], label=f'L={L}', color=colores[L], alpha=0.8)
    axs2[1].plot(fechas, resultados['real'][L]['Chi'], label=f'L={L}', color=colores[L], alpha=0.8)
    axs2[2].plot(fechas, resultados['real'][L]['Xi'], label=f'L={L}', color=colores[L], alpha=0.8)

axs2[0].set_ylabel('|M|'); axs2[0].legend(); axs2[0].grid(True, alpha=0.3)
axs2[1].set_ylabel(r'$\chi$'); axs2[1].legend(); axs2[1].grid(True, alpha=0.3)
axs2[2].set_ylabel(r'$\xi$'); axs2[2].legend(); axs2[2].grid(True, alpha=0.3)
plt.tight_layout()

# --- FIGURA 3: SCALING ---
fig3, axs3 = plt.subplots(1, 3, figsize=(16, 5))
fig3.suptitle('FIGURA 3: EFECTOS DE TAMAÑO FINITO EN FUNCIÓN DE L', fontsize=16, y=1.05)

M_mean_sim = [np.nanmean(resultados['sim'][L]['M']) for L in tamaños_L]
M_mean_real = [np.nanmean(resultados['real'][L]['M']) for L in tamaños_L]

Chi_max_sim = [np.nanmax(resultados['sim'][L]['Chi']) for L in tamaños_L]
Chi_max_real = [np.nanmax(resultados['real'][L]['Chi']) for L in tamaños_L]

Xi_mean_sim = [np.nanmean(resultados['sim'][L]['Xi']) for L in tamaños_L]
Xi_mean_real = [np.nanmean(resultados['real'][L]['Xi']) for L in tamaños_L]

axs3[0].plot(tamaños_L, M_mean_sim, 'o', color='red', label='Simulación', linewidth=2, markersize=8)
axs3[0].plot(tamaños_L, M_mean_real, 's', color='blue', label='Mercado Real', linewidth=2, markersize=8)
axs3[0].set_title(r'Magnetización Media $\langle |M| \rangle$')
axs3[0].set_xlabel('L (Tamaño Red)')
axs3[0].legend(); axs3[0].grid(True, alpha=0.4)

axs3[1].plot(tamaños_L, Chi_max_sim, 'o', color='red', label='Simulación', linewidth=2, markersize=8)
axs3[1].plot(tamaños_L, Chi_max_real, 's', color='blue', label='Mercado Real', linewidth=2, markersize=8)
axs3[1].set_title(r'Susceptibilidad Máxima $\chi_{max}$')
axs3[1].set_xlabel('L (Tamaño Red)')
axs3[1].legend(); axs3[1].grid(True, alpha=0.4)

axs3[2].plot(tamaños_L, Xi_mean_sim, 'o', color='red', label='Simulación', linewidth=2, markersize=8)
axs3[2].plot(tamaños_L, Xi_mean_real, 's', color='blue', label='Mercado Real', linewidth=2, markersize=8)
axs3[2].set_title(r'Longitud Correlación Media $\langle \xi \rangle$')
axs3[2].set_xlabel('L (Tamaño Red)')
axs3[2].legend(); axs3[2].grid(True, alpha=0.4)

plt.tight_layout()
plt.show()
# Out:
# Extrayendo S&P 1500 oficial... (Ordenando ALFABÉTICAMENTE para el experimento de control)
# Total empresas encontradas: 1506. Descargando años 2011-2012...
# $HOOD: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $KVUE: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $SDGR: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $BOX: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $NWS: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $UPWK: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $SOLV: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $IIPR: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $CTKB: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $FTRE: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $INSP: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $PRVA: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $KRYS: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $DEA: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $CLSK: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $NWSA: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $OSW: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $VITL: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $CTRE: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $WHD: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $PAYO: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $SOLS: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $ADT: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $PECO: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $AR: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $PLMR: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $ESAB: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $CCS: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $UNIT: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $AMTM: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $DV: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $VNT: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $VOYA: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $DFIN: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $PAHC: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $SFM: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $UE: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $SNCY: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $AHH: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $VSNT: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $EXPI: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $ECG: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $CRC: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $ARES: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $GSHD: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $SHC: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $COTY: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $DT: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $AHR: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $CEG: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $NABL: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $PSN: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $SMPL: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $ALRM: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $BROS: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $BLD: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $KGS: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $CWEN: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $DBX: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $CARG: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $CRBG: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $FND: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $BTU: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $SPNT: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $MCW: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $PR: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $PATH: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $WSC: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $CSW: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $HRMY: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $EXE: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $APLS: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $ZTS: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $NAVI: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $DFH: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $MIR: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $PCTY: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $VST: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $VSCO: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $ONTO: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $KNTK: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $RCUS: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $SABR: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $SITM: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $PLAY: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $DUOL: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $INSW: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $TTD: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $RUN: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $GKOS: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $NVST: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $CARR: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $IBP: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $AMPH: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $ELAN: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $ABNB: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $XNCR: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $VIRT: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $ENVA: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $OLLI: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $STEP: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $DOCN: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $PI: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $OGN: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $MEDP: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $PAYC: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $LBRT: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $TNDM: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $SAIC: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $FOUR: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $ABBV: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $LGIH: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $BTSG: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $BHF: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $AXTA: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $ICHR: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $HGV: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $TFIN: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $AAMI: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $CVNA: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $ACI: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $GEHC: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $VRRM: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $GOLF: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $HASI: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $BILL: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $VSTS: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $OTIS: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $WMG: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $CRSR: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $TLN: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $MUSA: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $VNOM: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $HQY: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $XYZ: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $VIR: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $FOXF: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $KN: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $VLTO: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $EMBC: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $REYN: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $DTM: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $EVTC: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $TALO: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $EYE: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $JXN: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $MGY: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $CART: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $IRT: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $ARMK: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $VAL: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $WAY: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $RRR: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $CAVA: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $OUT: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $APLE: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $DASH: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $GO: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $QTWO: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $SFBS: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $AVNS: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $HAYW: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $KREF: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $GTM: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $TRU: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $USFD: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $WFRD: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $GLPI: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $BJ: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $NATL: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $CWK: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $FTDR: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $ALLY: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $CERT: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $STEL: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $NTNX: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $NE: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $SEDG: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $CNXC: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $COLL: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $BCC: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $NXRT: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $HTZ: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $APG: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $JHG: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $LNTH: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $DNOW: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $TMDX: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $GDDY: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $BURL: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $APP: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $PSTG: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $HIMS: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $HWM: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $MSGS: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $ADMA: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $BL: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $MRNA: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $WH: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $CXM: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $SHAK: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $CFG: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $KEYS: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $YETI: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $ARLO: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $CRGY: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $DOCS: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $UBER: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $TRUP: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $RYAN: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $HLI: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $AESI: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $EPRT: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $CC: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $KD: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $COIN: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $LPG: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $SLVM: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $LW: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $CTVA: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $VTOL: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $GEV: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $RAL: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $REZI: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $AMR: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $CABO: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $CWEN-A: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $REXR: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $IR: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $FOXA: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $NSA: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $TPH: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# $APAM: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
#
# 733 Failed downloads:
# ['HOOD', 'KVUE', 'SDGR', 'BOX', 'NWS', 'UPWK', 'SOLV', 'IIPR', 'CTKB', 'FTRE', 'INSP', 'PRVA', 'KRYS', 'DEA', 'CLSK', 'NWSA', 'OSW', 'VITL', 'CTRE', 'WHD', 'PAYO', 'SOLS', 'ADT', 'PECO', 'AR', 'PLMR', 'ESAB', 'CCS', 'UNIT', 'AMTM', 'DV', 'VNT', 'VOYA', 'DFIN', 'PAHC', 'SFM', 'UE', 'SNCY', 'AHH', 'VSNT', 'EXPI', 'ECG', 'CRC', 'ARES', 'GSHD', 'SHC', 'COTY', 'DT', 'AHR', 'CEG', 'NABL', 'PSN', 'SMPL', 'ALRM', 'BROS', 'BLD', 'KGS', 'CWEN', 'DBX', 'CARG', 'CRBG', 'FND', 'BTU', 'SPNT', 'MCW', 'PR', 'PATH', 'WSC', 'CSW', 'HRMY', 'EXE', 'APLS', 'ZTS', 'NAVI', 'DFH', 'MIR', 'PCTY', 'VST', 'VSCO', 'ONTO', 'KNTK', 'RCUS', 'SABR', 'SITM', 'PLAY', 'DUOL', 'INSW', 'TTD', 'RUN', 'GKOS', 'NVST', 'CARR', 'IBP', 'AMPH', 'ELAN', 'ABNB', 'XNCR', 'VIRT', 'ENVA', 'OLLI', 'STEP', 'DOCN', 'PI', 'OGN', 'MEDP', 'PAYC', 'LBRT', 'TNDM', 'SAIC', 'FOUR', 'ABBV', 'LGIH', 'BTSG', 'BHF', 'AXTA', 'ICHR', 'HGV', 'TFIN', 'AAMI', 'CVNA', 'ACI', 'GEHC', 'VRRM', 'GOLF', 'HASI', 'BILL', 'VSTS', 'OTIS', 'WMG', 'CRSR', 'TLN', 'MUSA', 'VNOM', 'HQY', 'XYZ', 'VIR', 'FOXF', 'KN', 'VLTO', 'EMBC', 'REYN', 'DTM', 'EVTC', 'TALO', 'EYE', 'JXN', 'MGY', 'CART', 'IRT', 'ARMK', 'VAL', 'WAY', 'RRR', 'CAVA', 'OUT', 'APLE', 'DASH', 'GO', 'QTWO', 'SFBS', 'AVNS', 'HAYW', 'KREF', 'GTM', 'TRU', 'USFD', 'WFRD', 'GLPI', 'BJ', 'NATL', 'CWK', 'FTDR', 'ALLY', 'CERT', 'STEL', 'NTNX', 'NE', 'SEDG', 'CNXC', 'COLL', 'BCC', 'NXRT', 'HTZ', 'APG', 'JHG', 'LNTH', 'DNOW', 'TMDX', 'GDDY', 'BURL', 'APP', 'PSTG', 'HIMS', 'HWM', 'MSGS', 'ADMA', 'BL', 'MRNA', 'WH', 'CXM', 'SHAK', 'CFG', 'KEYS', 'YETI', 'ARLO', 'CRGY', 'DOCS', 'UBER', 'TRUP', 'RYAN', 'HLI', 'AESI', 'EPRT', 'CC', 'KD', 'COIN', 'LPG', 'SLVM', 'LW', 'CTVA', 'VTOL', 'GEV', 'RAL', 'REZI', 'AMR', 'CABO', 'CWEN-A', 'REXR', 'IR', 'FOXA', 'NSA', 'TPH', 'APAM']: possibly delisted; no price data found  (1d 2011-01-01 -> 2012-12-31) (Yahoo error = "Data doesn't exist for startDate = 1293858000, endDate = 1356930000")
# ['INVH', 'ALV', 'MDU', 'KHC', 'AHCO', 'PK', 'FSS', 'AXP', 'POWI', 'CLF', 'GM', 'HIG', 'NTCT', 'BANF', 'DDOG', 'PGNY', 'CASY', 'FTV', 'INTU', 'CSX', 'APPF', 'ESI', 'KNX', 'ADNT', 'AWR', 'ZWS', 'UNFI', 'HLT', 'MKTX', 'BAC', 'AIN', 'SWX', 'DHR', 'EG', 'CMI', 'AVTR', 'MC', 'UNF', 'LXP', 'KBR', 'APA', 'GOOG', 'PPL', 'FHB', 'USB', 'RBC', 'MSCI', 'OGS', 'CRK', 'SBAC', 'TWO', 'CVLT', 'LQDT', 'KEY', 'APH', 'AFG', 'NI', 'LZB', 'VICI', 'GOGO', 'MUR', 'Q', 'PJT', 'BG', 'VAC', 'THG', 'GPK', 'MRP', 'ATEN', 'ORA', 'XHR', 'WERN', 'FHI', 'FCPT', 'SLB', 'PIPR', 'NWBI', 'BEN', 'PHIN', 'SEE', 'CPAY', 'ST', 'CBSH', 'DAL', 'EFX', 'PVH', 'GNTX', 'ZBRA', 'EME', 'MLM', 'ABM', 'NOV', 'CF', 'TDG', 'TSLA', 'LPX', 'HUBG', 'PFGC', 'HAFC', 'PAG', 'CROX', 'RES', 'CRI', 'PWR', 'ANGI', 'CME', 'LNT', 'CAKE', 'SW', 'DLTR', 'CXW', 'ESE', 'BOOT', 'ACT', 'ELF', 'CMG', 'DECK', 'NWL', 'CI', 'FE', 'FBIN', 'VMI', 'SSB', 'PLNT', 'XPEL', 'CNXN', 'WDFC', 'VLO', 'PHM', 'ALGT', 'DIOD', 'CMC', 'PINS', 'CELH', 'PODD', 'FSLR', 'GT', 'HL', 'AMD', 'CURB', 'HLX', 'RAMP', 'OGE', 'CHWY', 'RTX', 'EHC', 'AIT', 'CSGS', 'WSFS', 'SNDR', 'STX', 'CATY', 'PRU', 'CRWD', 'MSEX', 'TILE', 'WD', 'PSX', 'ACMR', 'WING', 'G', 'JBTM', 'EOG', 'TBBK', 'ITGR', 'AVAV', 'ICUI', 'CTAS', 'FDP', 'TTWO', 'IIIN', 'TT', 'APOG', 'CMS', 'WMB', 'DOCU', 'SARO', 'AAPL', 'FRPT', 'UBSI', 'LKFN', 'CAT', 'AAP', 'CDP', 'GTY', 'ROIV', 'ADEA', 'IP', 'YOU', 'CBOE', 'O', 'BXMT', 'RVTY', 'NXPI', 'TKO', 'AMZN', 'JEF', 'SONO', 'LIVN', 'SNPS', 'AMH', 'HCC', 'DLR', 'DCOM', 'SYK', 'MCRI', 'LEG', 'TTC', 'PNW', 'IAC', 'JPM', 'RNG', 'MAA', 'ALLE', 'WMS', 'BYD', 'CHDN', 'CAG', 'COP', 'AN', 'GXO', 'PRIM', 'NVT', 'MBC', 'WSR', 'FHN', 'ALG', 'NXT', 'GEO', 'FOX', 'ATR', 'CDW', 'LITE', 'SEZL', 'JBGS', 'BBWI', 'IQV', 'GPC', 'SCHW', 'HMN', 'DGX', 'ALKS', 'FCFS', 'VFC', 'NSSC', 'LIN', 'UVV', 'CZR', 'JCI', 'PENG', 'GTLS', 'ABCB', 'WS', 'TGTX', 'EFC', 'WSM', 'ACA', 'KLIC', 'BBT', 'EBAY', 'BX', 'YUM', 'OKE', 'COLB', 'EPC', 'LDOS', 'SR', 'LULU', 'MOG-A', 'EXR', 'PTCT', 'MMS', 'PYPL', 'TROW', 'QRVO', 'GDYN', 'STZ', 'FTI', 'XYL', 'WAFD', 'TRMK', 'BRX', 'IT', 'ODFL', 'SO', 'BMY', 'FBRT', 'MOH', 'FCF', 'SXI', 'MMI', 'ES', 'SSD', 'VZ', 'SAFT', 'WCC', 'CCL', 'STAA', 'UCTT', 'BKH', 'ROP', 'ALGM', 'KRG', 'AZO', 'HPE', 'ANET', 'TWLO', 'ACAD', 'ESNT', 'OZK', 'PTGX', 'OPLN', 'ITT', 'CPF', 'MSM', 'PCAR', 'PENN', 'ACM', 'INCY', 'VRSK', 'AORT', 'SEM', 'PNFP', 'RGEN', 'GTES', 'CR', 'BAX', 'URBN', 'INDB', 'MRSH', 'AA', 'GILD', 'CTSH', 'OKTA', 'PLTR', 'KR', 'FIVE', 'AM', 'FIS', 'LH', 'DOC', 'VTR', 'KNF', 'BF-B', 'ULTA', 'JBLU', 'HALO', 'ATGE', 'WRLD', 'DRH', 'SEIC', 'ADSK', 'ED', 'INDV', 'VICR', 'HTLD', 'REG', 'MTDR', 'HUM', 'RNR', 'SGI', 'MBIN', 'LMT', 'PEP', 'CENT', 'CRVL', 'HAL', 'TNL', 'FMC', 'MCY', 'ALK', 'LOPE', 'HXL', 'BR', 'EQH', 'VVV', 'VCYT', 'CGNX', 'UPS', 'NBHC', 'ETSY', 'AVT', 'INVA', 'BRKR', 'GDEN', 'HWC', 'PRKS', 'UGI', 'VCTR', 'KTB', 'NEM', 'CFR', 'HPQ', 'LII', 'T', 'NGVT', 'TXRH', 'ATI', 'NUE', 'MATX', 'FCX', 'RXO', 'AXON', 'MO', 'MATW', 'DEI', 'FBK', 'CNM', 'SON', 'CSL', 'SRPT', 'WRB', 'EPAM', 'IVZ', 'AMRX', 'ASO', 'SCSC', 'NFLX', 'MTUS', 'CPK', 'FIZZ', 'HLNE', 'JAZZ', 'MP', 'TCBI', 'DOW', 'BSY', 'WEX', 'SIG', 'SNDK', 'SYY', 'PFG', 'BWXT', 'KWR', 'FUN', 'KNSL', 'OXY', 'MA', 'LZ', 'AVY', 'MLI', 'NX', 'CNR', 'ENR', 'IDCC', 'PRSU', 'SYF', 'APTV', 'BA', 'BBY', 'J', 'WYNN', 'CARS', 'EL', 'BKR', 'ULS', 'PAYX', 'MTSI', 'PRG', 'GNL', 'VRSN', 'OMCL', 'ACHC', 'SWK', 'POOL', 'APD', 'MTX', 'AMSF', 'HON', 'CON', 'CRS', 'KW', 'NMIH', 'PEN', 'UA', 'RRX', 'STRL', 'CAH', 'RH', 'FICO', 'BRBR', 'AEE', 'TMHC', 'DELL', 'SXC', 'RPM', 'TPR', 'CNH', 'CAR', 'PRLB', 'HII', 'DLB', 'KMI', 'WU', 'TRMB', 'ESS', 'NBIX', 'EIG', 'AVGO', 'NCLH']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# Han sobrevivido 741 empresas.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 115
#     113     print(f"¡Matriz ALFABÉTICA de {returns_real_base.shape[1]} empresas lista para L=32!")
#     114 else:
# --> 115     raise ValueError(f"FALTAN EMPRESAS: Solo sobrevivieron {returns_real_base.shape[1]}.")
#     116 # 3. BUCLE PRINCIPAL DE EXPERIMENTOS
#     117 # ==========================================
#     118 tamaños_L = [8, 16, 32]
#
# ValueError: FALTAN EMPRESAS: Solo sobrevivieron 741.

# %%
import numpy as np
from scipy.stats import linregress

# Convertimos las listas de la celda anterior a arrays de numpy
L_vals = np.array(tamaños_L)
log_L = np.log(L_vals)

log_M_real = np.log(np.array(M_mean_real))
log_Chi_real = np.log(np.array(Chi_max_real))
log_Xi_real = np.log(np.array(Xi_mean_real))

# ==========================================
# 1. AJUSTES LINEALES (LOG-LOG) PARA EXTRAER EXPONENTES
# ==========================================
# |M| ~ L^(-beta/nu) --> log(|M|) = (-beta/nu)*log(L) + C
slope_M, intercept_M, r_M, p_M, stderr_M = linregress(log_L, log_M_real)
exp_beta_nu = -slope_M  # Le cambiamos el signo para tener beta/nu positivo

# Chi ~ L^(gamma/nu) --> log(Chi) = (gamma/nu)*log(L) + C
slope_Chi, intercept_Chi, r_Chi, p_Chi, stderr_Chi = linregress(log_L, log_Chi_real)
exp_gamma_nu = slope_Chi

# Xi ~ L^x --> log(Xi) = x*log(L) + C
slope_Xi, intercept_Xi, r_Xi, p_Xi, stderr_Xi = linregress(log_L, log_Xi_real)
exp_xi = slope_Xi

# ==========================================
# 2. VALORES TEÓRICOS
# ==========================================
# Onsager (Ising 2D exacto): beta=1/8, gamma=7/4, nu=1
onsager_beta_nu = 0.125
onsager_gamma_nu = 1.75
onsager_xi = 1.0

# Campo Medio (Mean Field): beta=1/2, gamma=1, nu=1/2 
# (Los ratios beta/nu y gamma/nu en FSS clásico)
mf_beta_nu = 1.0
mf_gamma_nu = 2.0
mf_xi = 0.5 # En mean field la longitud de correlación escala con nu=1/2

# ==========================================
# 3. CÁLCULO DE DISTANCIAS EN SIGMAS
# ==========================================
# Función auxiliar para evitar división por cero si el ajuste es "demasiado perfecto"
def calc_sigma(empirico, teorico, error):
    if error < 1e-10: return float('inf')
    return abs(empirico - teorico) / error

sigmas = {
    'beta': {
        'Onsager': calc_sigma(exp_beta_nu, onsager_beta_nu, stderr_M),
        'MeanField': calc_sigma(exp_beta_nu, mf_beta_nu, stderr_M)
    },
    'gamma': {
        'Onsager': calc_sigma(exp_gamma_nu, onsager_gamma_nu, stderr_Chi),
        'MeanField': calc_sigma(exp_gamma_nu, mf_gamma_nu, stderr_Chi)
    },
    'xi': {
        'Onsager': calc_sigma(exp_xi, onsager_xi, stderr_Xi),
        'MeanField': calc_sigma(exp_xi, mf_xi, stderr_Xi)
    }
}

# ==========================================
# 4. IMPRESIÓN DE RESULTADOS
# ==========================================
print("=== ANÁLISIS DE EXPONENTES CRÍTICOS (MERCADO REAL) ===")
print(f"Basado en L = {tamaños_L}")
print("-" * 55)

print(f"1. PARÁMETRO DE ORDEN (beta/nu)")
print(f"   Exponente extraído:  {exp_beta_nu:.4f} ± {stderr_M:.4f}")
print(f"   Distancia Onsager:   {sigmas['beta']['Onsager']:.1f} sigmas (Teórico: {onsager_beta_nu})")
print(f"   Distancia C. Medio:  {sigmas['beta']['MeanField']:.1f} sigmas (Teórico: {mf_beta_nu})")
print("-" * 55)

print(f"2. SUSCEPTIBILIDAD (gamma/nu)")
print(f"   Exponente extraído:  {exp_gamma_nu:.4f} ± {stderr_Chi:.4f}")
print(f"   Distancia Onsager:   {sigmas['gamma']['Onsager']:.1f} sigmas (Teórico: {onsager_gamma_nu})")
print(f"   Distancia C. Medio:  {sigmas['gamma']['MeanField']:.1f} sigmas (Teórico: {mf_gamma_nu})")
print("-" * 55)

print(f"3. LONGITUD DE CORRELACIÓN (Exponente lineal)")
print(f"   Exponente extraído:  {exp_xi:.4f} ± {stderr_Xi:.4f}")
print(f"   Distancia Onsager:   {sigmas['xi']['Onsager']:.1f} sigmas (Teórico: {onsager_xi})")
print(f"   Distancia C. Medio:  {sigmas['xi']['MeanField']:.1f} sigmas (Teórico: {mf_xi})")
print("=" * 55)

# Opcional: Graficamos el ajuste log-log de la susceptibilidad para verlo
import matplotlib.pyplot as plt
plt.figure(figsize=(6, 4))
plt.errorbar(log_L, log_Chi_real, yerr=stderr_Chi, fmt='bs', label='Mercado Real')
plt.plot(log_L, intercept_Chi + slope_Chi * log_L, 'k--', label=f'Ajuste (Pendiente = {exp_gamma_nu:.2f})')
plt.title(r'Ajuste FSS Log-Log para Susceptibilidad $\chi_{max}$')
plt.xlabel(r'$\log(L)$')
plt.ylabel(r'$\log(\chi_{max})$')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()
# Out:
# === ANÁLISIS DE EXPONENTES CRÍTICOS (MERCADO REAL) ===
# Basado en L = [8, 16, 32]
# -------------------------------------------------------
# 1. PARÁMETRO DE ORDEN (beta/nu)
#    Exponente extraído:  -0.0066 ± 0.0123
#    Distancia Onsager:   10.7 sigmas (Teórico: 0.125)
#    Distancia C. Medio:  81.9 sigmas (Teórico: 1.0)
# -------------------------------------------------------
# 2. SUSCEPTIBILIDAD (gamma/nu)
#    Exponente extraído:  2.0130 ± 0.0021
#    Distancia Onsager:   127.7 sigmas (Teórico: 1.75)
#    Distancia C. Medio:  6.3 sigmas (Teórico: 2.0)
# -------------------------------------------------------
# 3. LONGITUD DE CORRELACIÓN (Exponente lineal)
#    Exponente extraído:  2.0601 ± 0.0202
#    Distancia Onsager:   52.4 sigmas (Teórico: 1.0)
#    Distancia C. Medio:  77.1 sigmas (Teórico: 0.5)
# =======================================================

# %%
import numpy as np
import pandas as pd
from scipy.stats import linregress

# Asumimos que 'returns_real_base', 'tamaños_L' y 'vent' (20) están en memoria
resultados_extra = {}

print("Calculando la Energía y el Calor Específico del mercado...")

for L in tamaños_L:
    N = L * L
    
    # Clonación de seguridad (igual que antes para mantener N)
    ret_real_N = returns_real_base.copy()
    intentos = 0
    while ret_real_N.shape[1] < N and intentos < 100:
        faltan = N - ret_real_N.shape[1]
        clon = returns_real_base.sample(n=min(returns_real_base.shape[1], faltan), axis=1)
        clon.columns = [f"CLON_{ret_real_N.shape[1] + i}" for i in range(clon.shape[1])]
        ret_real_N = pd.concat([ret_real_N, clon], axis=1)
        intentos += 1
        
    ret_real_N = ret_real_N.iloc[:, :N]
    spins_real = np.sign(ret_real_N).replace(0, 1).values  # Shape: (dias, N)
    
    # 1. CÁLCULO DE LA ENERGÍA TOPOLÓGICA (E)
    edges = []
    for index in range(N):
        row, col = index // L, index % L
        vecinos = [((row - 1) % L) * L + col, ((row + 1) % L) * L + col, 
                   row * L + (col - 1) % L, row * L + (col + 1) % L]
        for v in vecinos:
            if index < v: edges.append((index, v))
    edges = np.array(edges)
    
    # Interacción de espines: s_i * s_j
    interacciones = spins_real[:, edges[:, 0]] * spins_real[:, edges[:, 1]]
    # E = - Sum(s_i * s_j) / N
    E_dias = -np.sum(interacciones, axis=1) / float(N)
    
    # 2. CALOR ESPECÍFICO (C) = N * Var(E)
    C_real = pd.Series(E_dias).rolling(window=vent).var().values * N
    
    # Recuperamos M y Chi
    M_real = np.mean(spins_real, axis=1)
    Chi_real = pd.Series(M_real).rolling(window=vent).var().values * N
    
    resultados_extra[L] = {
        'C': C_real,
        'M': np.abs(M_real),
        'Chi': Chi_real
    }

# ==========================================
# EXTRACCIÓN DE RATIOS (AJUSTE LOG-LOG)
# ==========================================
L_vals = np.array(tamaños_L)
log_L = np.log(L_vals)

M_mean = [np.nanmean(resultados_extra[L]['M']) for L in tamaños_L]
Chi_max = [np.nanmax(resultados_extra[L]['Chi']) for L in tamaños_L]
C_max = [np.nanmax(resultados_extra[L]['C']) for L in tamaños_L]

# Ajustes
slope_M, _, _, _, _ = linregress(log_L, np.log(M_mean))
beta_nu = -slope_M  # |M| ~ L^(-beta/nu)

slope_Chi, _, _, _, _ = linregress(log_L, np.log(Chi_max))
gamma_nu = slope_Chi  # Chi ~ L^(gamma/nu)

slope_C, _, _, _, _ = linregress(log_L, np.log(C_max))
alpha_nu = slope_C  # C ~ L^(alpha/nu)

# ==========================================
# LEYES DE ESCALA (EL SISTEMA DE ECUACIONES)
# ==========================================
# 1. Ley de Rushbrooke: alpha + 2*beta + gamma = 2 
# Dividiendo por nu: (alpha/nu) + 2(beta/nu) + (gamma/nu) = 2/nu
suma_ratios = alpha_nu + 2.0 * beta_nu + gamma_nu
nu = 2.0 / suma_ratios

# Despejamos los individuales multiplicando por nu
alpha = alpha_nu * nu
beta = beta_nu * nu
gamma = gamma_nu * nu

# 2. Ley de Widom: delta = 1 + gamma/beta
delta = 1.0 + (gamma / beta) if beta != 0 else float('inf')

# 3. Ley de Fisher: gamma/nu = 2 - eta  => eta = 2 - gamma/nu
eta = 2.0 - gamma_nu

# ==========================================
# IMPRESIÓN DE LA CLASE DE UNIVERSALIDAD BURSÁTIL
# ==========================================
print("\n" + "="*60)
print("LA CLASE DE UNIVERSALIDAD DEL MERCADO (S&P 500)")
print("="*60)
print(f"1. Ratios FSS extraídos empíricamente:")
print(f"   alpha/nu  (Calor Específico): {alpha_nu:.4f}")
print(f"   beta/nu   (Magnetización):    {beta_nu:.4f}")
print(f"   gamma/nu  (Susceptibilidad):  {gamma_nu:.4f}")
print("-" * 60)
print("2. EXPONENTES CRÍTICOS INDIVIDUALES (Leyes de Escala):")
print(f"   [nu]     Longitud Correlación:  {nu:.4f}  (Teórico 2D: 1.0, Campo Medio: 0.5)")
print(f"   [alpha]  Calor Específico:      {alpha:.4f}  (Teórico 2D: 0.0, Campo Medio: 0.0)")
print(f"   [beta]   Parámetro de Orden:    {beta:.4f}  (Teórico 2D: 0.125, Campo Medio: 0.5)")
print(f"   [gamma]  Susceptibilidad:       {gamma:.4f}  (Teórico 2D: 1.75, Campo Medio: 1.0)")
print(f"   [delta]  Isoterma Crítica:      {delta:.4f}  (Teórico 2D: 15.0, Campo Medio: 3.0)")
print(f"   [eta]    Correlación Anómala:   {eta:.4f}  (Teórico 2D: 0.25, Campo Medio: 0.0)")
print("="*60)
# Out:
# Calculando la Energía y el Calor Específico del mercado...
#
# ============================================================
# LA CLASE DE UNIVERSALIDAD DEL MERCADO (S&P 500)
# ============================================================
# 1. Ratios FSS extraídos empíricamente:
#    alpha/nu  (Calor Específico): 1.8431
#    beta/nu   (Magnetización):    -0.0066
#    gamma/nu  (Susceptibilidad):  2.0130
# ------------------------------------------------------------
# 2. EXPONENTES CRÍTICOS INDIVIDUALES (Leyes de Escala):
#    [nu]     Longitud Correlación:  0.5204  (Teórico 2D: 1.0, Campo Medio: 0.5)
#    [alpha]  Calor Específico:      0.9592  (Teórico 2D: 0.0, Campo Medio: 0.0)
#    [beta]   Parámetro de Orden:    -0.0034  (Teórico 2D: 0.125, Campo Medio: 0.5)
#    [gamma]  Susceptibilidad:       1.0476  (Teórico 2D: 1.75, Campo Medio: 1.0)
#    [delta]  Isoterma Crítica:      -303.7794  (Teórico 2D: 15.0, Campo Medio: 3.0)
#    [eta]    Correlación Anómala:   -0.0130  (Teórico 2D: 0.25, Campo Medio: 0.0)
# ============================================================
